# %%
import json
import pandas as pd
import numpy as np
from datetime import datetime
import prettytable as pt
from matplotlib import pyplot as plt
import os
import warnings
warnings.filterwarnings("ignore")



###################################################################################################
                                                                                                  #
from rhoova.Client import *                                                                       #   
#Register and get api key from https://app.rhoova.com/ for ClientConfig("api key", "api secret")  #
config = ClientConfig("", "")                                                                     #
config = ClientConfig("gwr5J6VWP_VRV2SW5WqDg", "uldsvIkXREQN69mKzRPqwKH_XZIO7gZ3")                                                                     #
api = Api(config)                                                                                 # 
                                                                                                  #
###################################################################################################


directory = os.path.normpath(os.getcwd() + os.sep + os.pardir)
yielddatadirectory=directory+"/data/yielddata/bonddefiniton.csv"
marketdatadirectory=directory+"/data/marketdata/marketdata.csv"


bonddefiniton = pd.read_csv(yielddatadirectory)
marketdata = pd.read_csv(marketdatadirectory)

data=bonddefiniton.merge(marketdata[['valuationDate','isinCode','value']], left_on='isinCode', right_on='isinCode')
#data["valuationDate"]="2021-03-05"
#data['issueDate'] = data['issueDate'].apply(lambda x: datetime.strptime(x, "%d.%m.%Y").strftime("%Y-%m-%d"))
#data['maturityDate'] = data['maturityDate'].apply(lambda x: datetime.strptime(x, "%d.%m.%Y").strftime("%Y-%m-%d"))
# Out:
# array(['2021-03-05', '2021-06-18', '2020-09-25'], dtype=object)

# %%
 yieldData= [
    {
      "instrument": "BONDS",
      "isinCode": "TRT170822T15",
      "currency": "TRY",
      "couponRate": 0.0535,
      "frequency": "Semiannual",
      "maturityDate": "2022-08-17",
      "dayCounter": "ActualActual",
      "calendar": "Turkey",
      "issueDate": "2017-08-23",
      "redemption": 100,
      "dateGeneration": "Backward",
      "businessDayConvention": "ModifiedFollowing",
      "maturityDateConvention": "ModifiedFollowing",
      "endOfMonth": True,
      "yieldCurve": "TRY Bond Curve",
      "valuationDate": "2022-04-14",
      "value": 100.051,
      "cpiIndex": "",
      "baseCPI": "",
      "observationLag": "",
      "observationInterpolation": "",
      "growthOnly": ""
    },
    {
      "instrument": "BONDS",
      "isinCode": "TRT140922T17",
      "currency": "TRY",
      "couponRate": 0.0425,
      "frequency": "Semiannual",
      "maturityDate": "2022-09-14",
      "dayCounter": "ActualActual",
      "calendar": "Turkey",
      "issueDate": "2012-09-26",
      "redemption": 100,
      "dateGeneration": "Backward",
      "businessDayConvention": "ModifiedFollowing",
      "maturityDateConvention": "ModifiedFollowing",
      "endOfMonth": True,
      "yieldCurve": "TRY Bond Curve",
      "valuationDate": "2022-04-14",
      "value": 97.571,
      "cpiIndex": "",
      "baseCPI": "",
      "observationLag": "",
      "observationInterpolation": "",
      "growthOnly": ""
    },
    {
      "instrument": "BONDS",
      "isinCode": "TRT180123T10",
      "currency": "TRY",
      "couponRate": 0.061,
      "frequency": "Semiannual",
      "maturityDate": "2023-01-18",
      "dayCounter": "ActualActual",
      "calendar": "Turkey",
      "issueDate": "2018-01-24",
      "redemption": 100,
      "dateGeneration": "Backward",
      "businessDayConvention": "ModifiedFollowing",
      "maturityDateConvention": "ModifiedFollowing",
      "endOfMonth": True,
      "yieldCurve": "TRY Bond Curve",
      "valuationDate": "2022-04-14",
      "value": 97.342,
      "cpiIndex": "",
      "baseCPI": "",
      "observationLag": "",
      "observationInterpolation": "",
      "growthOnly": ""
    },
    {
      "instrument": "BONDS",
      "isinCode": "TRD050724T16",
      "currency": "TRY",
      "couponRate": 0.0115,
      "frequency": "Semiannual",
      "maturityDate": "2024-07-05",
      "dayCounter": "ActualActual",
      "calendar": "Turkey",
      "issueDate": "2021-07-09",
      "redemption": 100,
      "dateGeneration": "Backward",
      "businessDayConvention": "ModifiedFollowing",
      "maturityDateConvention": "ModifiedFollowing",
      "endOfMonth": True,
      "yieldCurve": "TRY Bond Curve",
      "valuationDate": "2022-04-14",
      "value": 92.499,
      "cpiIndex": "",
      "baseCPI": "",
      "observationLag": "",
      "observationInterpolation": "",
      "growthOnly": ""
    },
    {
      "instrument": "BONDS",
      "isinCode": "TRD120723T18",
      "currency": "TRY",
      "couponRate": 0.0904,
      "frequency": "Semiannual",
      "maturityDate": "2023-07-12",
      "dayCounter": "ActualActual",
      "calendar": "Turkey",
      "issueDate": "2021-07-14",
      "redemption": 100,
      "dateGeneration": "Backward",
      "businessDayConvention": "ModifiedFollowing",
      "maturityDateConvention": "ModifiedFollowing",
      "endOfMonth": True,
      "yieldCurve": "TRY Bond Curve",
      "valuationDate": "2022-04-14",
      "value": 104.537,
      "cpiIndex": "",
      "baseCPI": "",
      "observationLag": "",
      "observationInterpolation": "",
      "growthOnly": ""
    },
    {
      "instrument": "BONDS",
      "isinCode": "TRD200324T29",
      "currency": "TRY",
      "couponRate": 0.1215,
      "frequency": "Semiannual",
      "maturityDate": "2024-03-20",
      "dayCounter": "ActualActual",
      "calendar": "Turkey",
      "issueDate": "2022-03-23",
      "redemption": 100,
      "dateGeneration": "Backward",
      "businessDayConvention": "ModifiedFollowing",
      "maturityDateConvention": "ModifiedFollowing",
      "endOfMonth": True,
      "yieldCurve": "TRY Bond Curve",
      "valuationDate": "2022-04-14",
      "value": 104.355,
      "cpiIndex": "",
      "baseCPI": "",
      "observationLag": "",
      "observationInterpolation": "",
      "growthOnly": ""
    },
    {
      "instrument": "BONDS",
      "isinCode": "TRT011025T16",
      "currency": "TRY",
      "couponRate": 0.063,
      "frequency": "Semiannual",
      "maturityDate": "2025-10-01",
      "dayCounter": "ActualActual",
      "calendar": "Turkey",
      "issueDate": "2020-10-07",
      "redemption": 100,
      "dateGeneration": "Backward",
      "businessDayConvention": "ModifiedFollowing",
      "maturityDateConvention": "ModifiedFollowing",
      "endOfMonth": True,
      "yieldCurve": "TRY Bond Curve",
      "valuationDate": "2022-04-14",
      "value": 75.869,
      "cpiIndex": "",
      "baseCPI": "",
      "observationLag": "",
      "observationInterpolation": "",
      "growthOnly": ""
    },
    {
      "instrument": "BONDS",
      "isinCode": "TRT020926T17",
      "currency": "TRY",
      "couponRate": 0.0845,
      "frequency": "Semiannual",
      "maturityDate": "2026-09-02",
      "dayCounter": "ActualActual",
      "calendar": "Turkey",
      "issueDate": "2021-09-08",
      "redemption": 100,
      "dateGeneration": "Backward",
      "businessDayConvention": "ModifiedFollowing",
      "maturityDateConvention": "ModifiedFollowing",
      "endOfMonth": True,
      "yieldCurve": "TRY Bond Curve",
      "valuationDate": "2022-04-14",
      "value": 83.574,
      "cpiIndex": "",
      "baseCPI": "",
      "observationLag": "",
      "observationInterpolation": "",
      "growthOnly": ""
    },
    {
      "instrument": "BONDS",
      "isinCode": "TRT080323T10",
      "currency": "TRY",
      "couponRate": 0.0355,
      "frequency": "Semiannual",
      "maturityDate": "2023-03-08",
      "dayCounter": "ActualActual",
      "calendar": "Turkey",
      "issueDate": "2013-03-20",
      "redemption": 100,
      "dateGeneration": "Backward",
      "businessDayConvention": "ModifiedFollowing",
      "maturityDateConvention": "ModifiedFollowing",
      "endOfMonth": True,
      "yieldCurve": "TRY Bond Curve",
      "valuationDate": "2022-04-14",
      "value": 90.002,
      "cpiIndex": "",
      "baseCPI": "",
      "observationLag": "",
      "observationInterpolation": "",
      "growthOnly": ""
    },
    {
      "instrument": "BONDS",
      "isinCode": "TRT131130T14",
      "currency": "TRY",
      "couponRate": 0.0585,
      "frequency": "Semiannual",
      "maturityDate": "2030-11-13",
      "dayCounter": "ActualActual",
      "calendar": "Turkey",
      "issueDate": "2020-11-25",
      "redemption": 100,
      "dateGeneration": "Backward",
      "businessDayConvention": "ModifiedFollowing",
      "maturityDateConvention": "ModifiedFollowing",
      "endOfMonth": True,
      "yieldCurve": "TRY Bond Curve",
      "valuationDate": "2022-04-14",
      "value": 63.452,
      "cpiIndex": "",
      "baseCPI": "",
      "observationLag": "",
      "observationInterpolation": "",
      "growthOnly": ""
    },
    {
      "instrument": "BONDS",
      "isinCode": "TRT140623T19",
      "currency": "TRY",
      "couponRate": 0.081,
      "frequency": "Semiannual",
      "maturityDate": "2023-06-14",
      "dayCounter": "ActualActual",
      "calendar": "Turkey",
      "issueDate": "2018-06-20",
      "redemption": 100,
      "dateGeneration": "Backward",
      "businessDayConvention": "ModifiedFollowing",
      "maturityDateConvention": "ModifiedFollowing",
      "endOfMonth": True,
      "yieldCurve": "TRY Bond Curve",
      "valuationDate": "2022-04-14",
      "value": 100.141,
      "cpiIndex": "",
      "baseCPI": "",
      "observationLag": "",
      "observationInterpolation": "",
      "growthOnly": ""
    },
    {
      "instrument": "BONDS",
      "isinCode": "TRT181023T19",
      "currency": "TRY",
      "couponRate": 0.1005,
      "frequency": "Semiannual",
      "maturityDate": "2023-10-18",
      "dayCounter": "ActualActual",
      "calendar": "Turkey",
      "issueDate": "2018-10-24",
      "redemption": 100,
      "dateGeneration": "Backward",
      "businessDayConvention": "ModifiedFollowing",
      "maturityDateConvention": "ModifiedFollowing",
      "endOfMonth": True,
      "yieldCurve": "TRY Bond Curve",
      "valuationDate": "2022-04-14",
      "value": 107.719,
      "cpiIndex": "",
      "baseCPI": "",
      "observationLag": "",
      "observationInterpolation": "",
      "growthOnly": ""
    },
    {
      "instrument": "BONDS",
      "isinCode": "TRT200923T18",
      "currency": "TRY",
      "couponRate": 0.086,
      "frequency": "Semiannual",
      "maturityDate": "2023-09-20",
      "dayCounter": "ActualActual",
      "calendar": "Turkey",
      "issueDate": "2021-09-22",
      "redemption": 100,
      "dateGeneration": "Backward",
      "businessDayConvention": "ModifiedFollowing",
      "maturityDateConvention": "ModifiedFollowing",
      "endOfMonth": True,
      "yieldCurve": "TRY Bond Curve",
      "valuationDate": "2022-04-14",
      "value": 95.94,
      "cpiIndex": "",
      "baseCPI": "",
      "observationLag": "",
      "observationInterpolation": "",
      "growthOnly": ""
    },
    {
      "instrument": "BONDS",
      "isinCode": "TRT240724T15",
      "currency": "TRY",
      "couponRate": 0.045,
      "frequency": "Semiannual",
      "maturityDate": "2024-07-24",
      "dayCounter": "ActualActual",
      "calendar": "Turkey",
      "issueDate": "2014-08-06",
      "redemption": 100,
      "dateGeneration": "Backward",
      "businessDayConvention": "ModifiedFollowing",
      "maturityDateConvention": "ModifiedFollowing",
      "endOfMonth": True,
      "yieldCurve": "TRY Bond Curve",
      "valuationDate": "2022-04-14",
      "value": 78.929,
      "cpiIndex": "",
      "baseCPI": "",
      "observationLag": "",
      "observationInterpolation": "",
      "growthOnly": ""
    },
    {
      "instrument": "BONDS",
      "isinCode": "TRT270923T11",
      "currency": "TRY",
      "couponRate": 0.044,
      "frequency": "Semiannual",
      "maturityDate": "2023-09-27",
      "dayCounter": "ActualActual",
      "calendar": "Turkey",
      "issueDate": "2013-10-09",
      "redemption": 100,
      "dateGeneration": "Backward",
      "businessDayConvention": "ModifiedFollowing",
      "maturityDateConvention": "ModifiedFollowing",
      "endOfMonth": True,
      "yieldCurve": "TRY Bond Curve",
      "valuationDate": "2022-04-14",
      "value": 85.063,
      "cpiIndex": "",
      "baseCPI": "",
      "observationLag": "",
      "observationInterpolation": "",
      "growthOnly": ""
    }]

# %%
yieldData
# Out:
# [{'instrument': 'BONDS',
#   'isinCode': 'TRT170822T15',
#   'currency': 'TRY',
#   'couponRate': 0.0535,
#   'frequency': 'Semiannual',
#   'maturityDate': '2022-08-17',
#   'dayCounter': 'ActualActual',
#   'calendar': 'Turkey',
#   'issueDate': '2017-08-23',
#   'redemption': 100,
#   'dateGeneration': 'Backward',
#   'businessDayConvention': 'ModifiedFollowing',
#   'maturityDateConvention': 'ModifiedFollowing',
#   'endOfMonth': True,
#   'yieldCurve': 'TRY Bond Curve',
#   'valuationDate': '2022-04-14',
#   'value': 100.051,
#   'cpiIndex': '',
#   'baseCPI': '',
#   'observationLag': '',
#   'observationInterpolation': '',
#   'growthOnly': ''},
#  {'instrument': 'BONDS',
#   'isinCode': 'TRT140922T17',
#   'currency': 'TRY',
#   'couponRate': 0.0425,
#   'frequency': 'Semiannual',
#   'maturityDate': '2022-09-14',
#   'dayCounter': 'ActualActual',
#   'calendar': 'Turkey',
#   'issueDate': '2012-09-26',
#   'redemption': 100,
#   'dateGeneration': 'Backward',
#   'businessDayConvention': 'ModifiedFollowing',
#   'maturityDateConvention': 'ModifiedFollowing',
#   'endOfMonth': True,
#   'yieldCurve': 'TRY Bond Curve',
#   'valuationDate': '2022-04-14',
#   'value': 97.571,
#   'cpiIndex': '',
#   'baseCPI': '',
#   'observationLag': '',
#   'observationInterpolation': '',
#   'growthOnly': ''},
#  {'instrument': 'BONDS',
#   'isinCode': 'TRT180123T10',
#   'currency': 'TRY',
#   'couponRate': 0.061,
#   'frequency': 'Semiannual',
#   'maturityDate': '2023-01-18',
#   'dayCounter': 'ActualActual',
#   'calendar': 'Turkey',
#   'issueDate': '2018-01-24',
#   'redemption': 100,
#   'dateGeneration': 'Backward',
#   'businessDayConvention': 'ModifiedFollowing',
#   'maturityDateConvention': 'ModifiedFollowing',
#   'endOfMonth': True,
#   'yieldCurve': 'TRY Bond Curve',
#   'valuationDate': '2022-04-14',
#   'value': 97.342,
#   'cpiIndex': '',
#   'baseCPI': '',
#   'observationLag': '',
#   'observationInterpolation': '',
#   'growthOnly': ''},
#  {'instrument': 'BONDS',
#   'isinCode': 'TRD050724T16',
#   'currency': 'TRY',
#   'couponRate': 0.0115,
#   'frequency': 'Semiannual',
#   'maturityDate': '2024-07-05',
#   'dayCounter': 'ActualActual',
#   'calendar': 'Turkey',
#   'issueDate': '2021-07-09',
#   'redemption': 100,
#   'dateGeneration': 'Backward',
#   'businessDayConvention': 'ModifiedFollowing',
#   'maturityDateConvention': 'ModifiedFollowing',
#   'endOfMonth': True,
#   'yieldCurve': 'TRY Bond Curve',
#   'valuationDate': '2022-04-14',
#   'value': 92.499,
#   'cpiIndex': '',
#   'baseCPI': '',
#   'observationLag': '',
#   'observationInterpolation': '',
#   'growthOnly': ''},
#  {'instrument': 'BONDS',
#   'isinCode': 'TRD120723T18',
#   'currency': 'TRY',
#   'couponRate': 0.0904,
#   'frequency': 'Semiannual',
#   'maturityDate': '2023-07-12',
#   'dayCounter': 'ActualActual',
#   'calendar': 'Turkey',
#   'issueDate': '2021-07-14',
#   'redemption': 100,
#   'dateGeneration': 'Backward',
#   'businessDayConvention': 'ModifiedFollowing',
#   'maturityDateConvention': 'ModifiedFollowing',
#   'endOfMonth': True,
#   'yieldCurve': 'TRY Bond Curve',
#   'valuationDate': '2022-04-14',
#   'value': 104.537,
#   'cpiIndex': '',
#   'baseCPI': '',
#   'observationLag': '',
#   'observationInterpolation': '',
#   'growthOnly': ''},
#  {'instrument': 'BONDS',
#   'isinCode': 'TRD200324T29',
#   'currency': 'TRY',
#   'couponRate': 0.1215,
#   'frequency': 'Semiannual',
#   'maturityDate': '2024-03-20',
#   'dayCounter': 'ActualActual',
#   'calendar': 'Turkey',
#   'issueDate': '2022-03-23',
#   'redemption': 100,
#   'dateGeneration': 'Backward',
#   'businessDayConvention': 'ModifiedFollowing',
#   'maturityDateConvention': 'ModifiedFollowing',
#   'endOfMonth': True,
#   'yieldCurve': 'TRY Bond Curve',
#   'valuationDate': '2022-04-14',
#   'value': 104.355,
#   'cpiIndex': '',
#   'baseCPI': '',
#   'observationLag': '',
#   'observationInterpolation': '',
#   'growthOnly': ''},
#  {'instrument': 'BONDS',
#   'isinCode': 'TRT011025T16',
#   'currency': 'TRY',
#   'couponRate': 0.063,
#   'frequency': 'Semiannual',
#   'maturityDate': '2025-10-01',
#   'dayCounter': 'ActualActual',
#   'calendar': 'Turkey',
#   'issueDate': '2020-10-07',
#   'redemption': 100,
#   'dateGeneration': 'Backward',
#   'businessDayConvention': 'ModifiedFollowing',
#   'maturityDateConvention': 'ModifiedFollowing',
#   'endOfMonth': True,
#   'yieldCurve': 'TRY Bond Curve',
#   'valuationDate': '2022-04-14',
#   'value': 75.869,
#   'cpiIndex': '',
#   'baseCPI': '',
#   'observationLag': '',
#   'observationInterpolation': '',
#   'growthOnly': ''},
#  {'instrument': 'BONDS',
#   'isinCode': 'TRT020926T17',
#   'currency': 'TRY',
#   'couponRate': 0.0845,
#   'frequency': 'Semiannual',
#   'maturityDate': '2026-09-02',
#   'dayCounter': 'ActualActual',
#   'calendar': 'Turkey',
#   'issueDate': '2021-09-08',
#   'redemption': 100,
#   'dateGeneration': 'Backward',
#   'businessDayConvention': 'ModifiedFollowing',
#   'maturityDateConvention': 'ModifiedFollowing',
#   'endOfMonth': True,
#   'yieldCurve': 'TRY Bond Curve',
#   'valuationDate': '2022-04-14',
#   'value': 83.574,
#   'cpiIndex': '',
#   'baseCPI': '',
#   'observationLag': '',
#   'observationInterpolation': '',
#   'growthOnly': ''},
#  {'instrument': 'BONDS',
#   'isinCode': 'TRT080323T10',
#   'currency': 'TRY',
#   'couponRate': 0.0355,
#   'frequency': 'Semiannual',
#   'maturityDate': '2023-03-08',
#   'dayCounter': 'ActualActual',
#   'calendar': 'Turkey',
#   'issueDate': '2013-03-20',
#   'redemption': 100,
#   'dateGeneration': 'Backward',
#   'businessDayConvention': 'ModifiedFollowing',
#   'maturityDateConvention': 'ModifiedFollowing',
#   'endOfMonth': True,
#   'yieldCurve': 'TRY Bond Curve',
#   'valuationDate': '2022-04-14',
#   'value': 90.002,
#   'cpiIndex': '',
#   'baseCPI': '',
#   'observationLag': '',
#   'observationInterpolation': '',
#   'growthOnly': ''},
#  {'instrument': 'BONDS',
#   'isinCode': 'TRT131130T14',
#   'currency': 'TRY',
#   'couponRate': 0.0585,
#   'frequency': 'Semiannual',
#   'maturityDate': '2030-11-13',
#   'dayCounter': 'ActualActual',
#   'calendar': 'Turkey',
#   'issueDate': '2020-11-25',
#   'redemption': 100,
#   'dateGeneration': 'Backward',
#   'businessDayConvention': 'ModifiedFollowing',
#   'maturityDateConvention': 'ModifiedFollowing',
#   'endOfMonth': True,
#   'yieldCurve': 'TRY Bond Curve',
#   'valuationDate': '2022-04-14',
#   'value': 63.452,
#   'cpiIndex': '',
#   'baseCPI': '',
#   'observationLag': '',
#   'observationInterpolation': '',
#   'growthOnly': ''},
#  {'instrument': 'BONDS',
#   'isinCode': 'TRT140623T19',
#   'currency': 'TRY',
#   'couponRate': 0.081,
#   'frequency': 'Semiannual',
#   'maturityDate': '2023-06-14',
#   'dayCounter': 'ActualActual',
#   'calendar': 'Turkey',
#   'issueDate': '2018-06-20',
#   'redemption': 100,
#   'dateGeneration': 'Backward',
#   'businessDayConvention': 'ModifiedFollowing',
#   'maturityDateConvention': 'ModifiedFollowing',
#   'endOfMonth': True,
#   'yieldCurve': 'TRY Bond Curve',
#   'valuationDate': '2022-04-14',
#   'value': 100.141,
#   'cpiIndex': '',
#   'baseCPI': '',
#   'observationLag': '',
#   'observationInterpolation': '',
#   'growthOnly': ''},
#  {'instrument': 'BONDS',
#   'isinCode': 'TRT181023T19',
#   'currency': 'TRY',
#   'couponRate': 0.1005,
#   'frequency': 'Semiannual',
#   'maturityDate': '2023-10-18',
#   'dayCounter': 'ActualActual',
#   'calendar': 'Turkey',
#   'issueDate': '2018-10-24',
#   'redemption': 100,
#   'dateGeneration': 'Backward',
#   'businessDayConvention': 'ModifiedFollowing',
#   'maturityDateConvention': 'ModifiedFollowing',
#   'endOfMonth': True,
#   'yieldCurve': 'TRY Bond Curve',
#   'valuationDate': '2022-04-14',
#   'value': 107.719,
#   'cpiIndex': '',
#   'baseCPI': '',
#   'observationLag': '',
#   'observationInterpolation': '',
#   'growthOnly': ''},
#  {'instrument': 'BONDS',
#   'isinCode': 'TRT200923T18',
#   'currency': 'TRY',
#   'couponRate': 0.086,
#   'frequency': 'Semiannual',
#   'maturityDate': '2023-09-20',
#   'dayCounter': 'ActualActual',
#   'calendar': 'Turkey',
#   'issueDate': '2021-09-22',
#   'redemption': 100,
#   'dateGeneration': 'Backward',
#   'businessDayConvention': 'ModifiedFollowing',
#   'maturityDateConvention': 'ModifiedFollowing',
#   'endOfMonth': True,
#   'yieldCurve': 'TRY Bond Curve',
#   'valuationDate': '2022-04-14',
#   'value': 95.94,
#   'cpiIndex': '',
#   'baseCPI': '',
#   'observationLag': '',
#   'observationInterpolation': '',
#   'growthOnly': ''},
#  {'instrument': 'BONDS',
#   'isinCode': 'TRT240724T15',
#   'currency': 'TRY',
#   'couponRate': 0.045,
#   'frequency': 'Semiannual',
#   'maturityDate': '2024-07-24',
#   'dayCounter': 'ActualActual',
#   'calendar': 'Turkey',
#   'issueDate': '2014-08-06',
#   'redemption': 100,
#   'dateGeneration': 'Backward',
#   'businessDayConvention': 'ModifiedFollowing',
#   'maturityDateConvention': 'ModifiedFollowing',
#   'endOfMonth': True,
#   'yieldCurve': 'TRY Bond Curve',
#   'valuationDate': '2022-04-14',
#   'value': 78.929,
#   'cpiIndex': '',
#   'baseCPI': '',
#   'observationLag': '',
#   'observationInterpolation': '',
#   'growthOnly': ''},
#  {'instrument': 'BONDS',
#   'isinCode': 'TRT270923T11',
#   'currency': 'TRY',
#   'couponRate': 0.044,
#   'frequency': 'Semiannual',
#   'maturityDate': '2023-09-27',
#   'dayCounter': 'ActualActual',
#   'calendar': 'Turkey',
#   'issueDate': '2013-10-09',
#   'redemption': 100,
#   'dateGeneration': 'Backward',
#   'businessDayConvention': 'ModifiedFollowing',
#   'maturityDateConvention': 'ModifiedFollowing',
#   'endOfMonth': True,
#   'yieldCurve': 'TRY Bond Curve',
#   'valuationDate': '2022-04-14',
#   'value': 85.063,
#   'cpiIndex': '',
#   'baseCPI': '',
#   'observationLag': '',
#   'observationInterpolation': '',
#   'growthOnly': ''}]

# %%
instruments={}
bonds={}
bonds["method"]="NelsonSiegel"
bonds["numberOfIterations"]=10000
bonds["accuracy"]=0.000001
bonds["simplexLambda"]=10
bonds["settlementDays"]=2
instruments["BONDS"]=bonds
instruments
# Out:
# {'BONDS': {'method': 'NelsonSiegel',
#   'numberOfIterations': 10000,
#   'accuracy': 1e-06,
#   'simplexLambda': 10,
#   'settlementDays': 2}}

# %%
yieldCurve={}
yieldCurve["settlementDays"]=2
yieldCurve["calendar"]="NullCalendar" 
yieldCurve["currency"]="TRY" # Currency is using filter yield data. Only same currency datas are filtered for bond calculation
yieldCurve["dayCounter"]="Thirty360E" # Default value is Actual360
yieldCurve["period"]="6M" # Can not use if instruments selected BONDS
yieldCurve["intpMethod"]="Linear" # if method is not null, it will not used
yieldCurve["instruments"]=instruments
yieldCurve
# Out:
# {'settlementDays': 2,
#  'calendar': 'NullCalendar',
#  'currency': 'TRY',
#  'dayCounter': 'Thirty360E',
#  'period': '6M',
#  'intpMethod': 'Linear',
#  'instruments': {'BONDS': {'method': 'NelsonSiegel',
#    'numberOfIterations': 10000,
#    'accuracy': 1e-06,
#    'simplexLambda': 10,
#    'settlementDays': 2}}}

# %%
ycresult ={
  "valuationDate": "2022-04-14",
  "yieldCurve": yieldCurve,
  "yieldData": yieldData
}

# %%
try:
    result = api.createTask(CalculationType.YIELD_CURVE, ycresult,True)
    nsresult=json.loads(result["result"])
except RhoovaError as e:
    e.printPretty()

# %%
nsresult
# Out:
# {'yieldNodeData': [{'date': '2022-08-17', 'rate': 0.08627391234061224},
#   {'date': '2022-09-14', 'rate': 0.08709473806743283},
#   {'date': '2023-01-18', 'rate': 0.09100799200169565},
#   {'date': '2023-03-08', 'rate': 0.09265350844292036},
#   {'date': '2023-06-14', 'rate': 0.09592325324361653},
#   {'date': '2023-07-12', 'rate': 0.09690440797018335},
#   {'date': '2023-09-20', 'rate': 0.09933899436566804},
#   {'date': '2023-09-27', 'rate': 0.09959377589208138},
#   {'date': '2023-10-18', 'rate': 0.10036277497978145},
#   {'date': '2024-03-20', 'rate': 0.10613544291468502},
#   {'date': '2024-07-05', 'rate': 0.11033060561119724},
#   {'date': '2024-07-24', 'rate': 0.11110724372984056},
#   {'date': '2025-10-01', 'rate': 0.12977411846504253},
#   {'date': '2026-09-02', 'rate': 0.14509995034656417},
#   {'date': '2030-11-13', 'rate': 0.12071983451247037}],
#  'zeroRates': [{'rate': 0.08627391234061224, 'date': '2022-08-17'},
#   {'rate': 0.08709473806743283, 'date': '2022-09-14'},
#   {'rate': 0.09100799200169565, 'date': '2023-01-18'},
#   {'rate': 0.09265350844292036, 'date': '2023-03-08'},
#   {'rate': 0.09592325324361653, 'date': '2023-06-14'},
#   {'rate': 0.09690440797018335, 'date': '2023-07-12'},
#   {'rate': 0.09933899436566804, 'date': '2023-09-20'},
#   {'rate': 0.09959377589208138, 'date': '2023-09-27'},
#   {'rate': 0.10036277497978145, 'date': '2023-10-18'},
#   {'rate': 0.10613544291468502, 'date': '2024-03-20'},
#   {'rate': 0.11033060561119724, 'date': '2024-07-05'},
#   {'rate': 0.11110724372984056, 'date': '2024-07-24'},
#   {'rate': 0.12977411846504253, 'date': '2025-10-01'},
#   {'rate': 0.14509995034656417, 'date': '2026-09-02'},
#   {'rate': 0.12071983451247037, 'date': '2030-11-13'}],
#  'discountRates': [{'rate': 0.9709532869361877, 'date': '2022-08-17'},
#   {'rate': 0.9643610954231968, 'date': '2022-09-14'},
#   {'rate': 0.9330773341843388, 'date': '2023-01-18'},
#   {'rate': 0.9199939752529159, 'date': '2023-03-08'},
#   {'rate': 0.894124311913886, 'date': '2023-06-14'},
#   {'rate': 0.8863954003479959, 'date': '2023-07-12'},
#   {'rate': 0.8672865130413875, 'date': '2023-09-20'},
#   {'rate': 0.8652925471585879, 'date': '2023-09-27'},
#   {'rate': 0.8592809841154331, 'date': '2023-10-18'},
#   {'rate': 0.8144883212166353, 'date': '2024-03-20'},
#   {'rate': 0.7823245511545212, 'date': '2024-07-05'},
#   {'rate': 0.7764076219323857, 'date': '2024-07-24'},
#   {'rate': 0.6379322917732044, 'date': '2025-10-01'},
#   {'rate': 0.5293944625949739, 'date': '2026-09-02'},
#   {'rate': 0.3549269637134517, 'date': '2030-11-13'}]}

# %%
nszerorates=nsresult.get("zeroRates")
nszeros={}
for i in nszerorates:
    nszeros[datetime.strptime(i.get("date"), "%Y-%m-%d")]=i.get("rate")
nszeros=dict(sorted(nszeros.items()))

# %%
yieldCurve["instruments"]["BONDS"]["method"]="Svensson"
try:
    result = api.createTask(CalculationType.YIELD_CURVE, ycresult,True)
    svresult=json.loads(result["result"])
except RhoovaError as e:
    e.printPretty()

# %%
svzerorates=svresult.get("zeroRates")
svzeros={}
for i in svzerorates:
    svzeros[datetime.strptime(i.get("date"), "%Y-%m-%d")]=i.get("rate")
svzeros=dict(sorted(svzeros.items()))

# %%
yieldCurve["instruments"]["BONDS"]["method"]="CubicBSplines"
try:
    result = api.createTask(CalculationType.YIELD_CURVE, ycresult,True)
    cbresult=json.loads(result["result"])
except RhoovaError as e:
    e.printPretty()

# %%
cbzerorates=cbresult.get("zeroRates")
cbzeros={}
for i in cbzerorates:
    cbzeros[datetime.strptime(i.get("date"), "%Y-%m-%d")]=i.get("rate")
cbzeros=dict(sorted(cbzeros.items()))

# %%
yieldCurve["instruments"]["BONDS"]["method"]="ExponentialSplines"
try:
    result = api.createTask(CalculationType.YIELD_CURVE, ycresult,True)
    exresult=json.loads(result["result"])
except RhoovaError as e:
    e.printPretty()

# %%
exzerorates=exresult.get("zeroRates")
exzeros={}
for i in exzerorates:
    exzeros[datetime.strptime(i.get("date"), "%Y-%m-%d")]=i.get("rate")
exzeros=dict(sorted(exzeros.items()))

# %%
yieldCurve["instruments"]["BONDS"]["method"]="SimplePolynomial"
try:
    result = api.createTask(CalculationType.YIELD_CURVE, ycresult,True)
    spresult=json.loads(result["result"])
except RhoovaError as e:
    e.printPretty()

# %%
spzerorates=spresult.get("zeroRates")
spzeros={}
for i in spzerorates:
    spzeros[datetime.strptime(i.get("date"), "%Y-%m-%d")]=i.get("rate")
spzeros=dict(sorted(spzeros.items()))

# %%
yieldCurve["instruments"]["BONDS"]["method"]=""
try:
    result = api.createTask(CalculationType.YIELD_CURVE, ycresult,True)
    pwresult=json.loads(result["result"])
except RhoovaError as e:
    e.printPretty()

# %%
pwzerorates=pwresult.get("zeroRates")
pwzeros={}
for i in pwzerorates:
    pwzeros[datetime.strptime(i.get("date"), "%Y-%m-%d")]=i.get("rate")
pwzeros=dict(sorted(pwzeros.items()))

# %%
fig, ax = plt.subplots(figsize=(20, 10))

x=list(nszeros.keys()) 
y1 =list(nszeros.values()) 
y2 =list(svzeros.values()) 
y3 =list(cbzeros.values()) 
y4 =list(exzeros.values()) 
y5 =list(spzeros.values()) 
#y6 =list(pwzeros.values()) 


ax.plot(x,y1, 'green', label='NelsonSiegel', linewidth=2)
ax.plot(x,y2, 'orange', label='Svensson', linewidth=2)
ax.plot(x,y3, 'red', label='Cubic Splines', linewidth=2)
ax.plot(x,y4, 'blue', label='Exponential Splines', linewidth=2)
ax.plot(x,y5, 'yellow', label='Simple Polynomial(3)', linewidth=2)
#ax.plot(x,y6, 'o', label='Piecewise Linear', linewidth=2)


leg = ax.legend(prop={'size': 16});
plt.grid(linestyle='dashdot')
plt.show()

# %%
ycresult
# Out:
# {'valuationDate': '2021-03-05',
#  'yieldCurve': {'settlementDays': 2,
#   'calendar': 'NullCalendar',
#   'currency': 'USD',
#   'dayCounter': 'Thirty360E',
#   'period': '6M',
#   'intpMethod': 'Linear',
#   'instrument': {'BONDS': {'method': 'NelsonSiegel',
#     'numberOfIterations': 10000,
#     'accuracy': 1e-06,
#     'simplexLambda': 10,
#     'settlementDays': 2}}},
#  'yieldData': [{'isincode': 'US900123CM05',
#    'currency': 'USD',
#    'couponRate': 0.0575,
#    'frequency': 'Semiannual',
#    'maturityDate': '2047-05-11',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2017-05-11',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 86.13},
#   {'isincode': 'US900123DC14',
#    'currency': 'USD',
#    'couponRate': 0.05875,
#    'frequency': 'Semiannual',
#    'maturityDate': '2031-06-26',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2021-01-26',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 97.341},
#   {'isincode': 'US900123AW05',
#    'currency': 'USD',
#    'couponRate': 0.07375,
#    'frequency': 'Semiannual',
#    'maturityDate': '2025-02-05',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2005-01-24',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 109.814},
#   {'isincode': 'US900123DB31',
#    'currency': 'USD',
#    'couponRate': 0.0475,
#    'frequency': 'Semiannual',
#    'maturityDate': '2026-01-26',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2021-01-26',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 99.1575},
#   {'isincode': 'US900123DA57',
#    'currency': 'USD',
#    'couponRate': 0.0595,
#    'frequency': 'Semiannual',
#    'maturityDate': '2031-01-15',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2020-12-02',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 98.3245},
#   {'isincode': 'US900123AY60',
#    'currency': 'USD',
#    'couponRate': 0.06875,
#    'frequency': 'Semiannual',
#    'maturityDate': '2036-03-17',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2006-01-17',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 101.7875},
#   {'isincode': 'US900123CB40',
#    'currency': 'USD',
#    'couponRate': 0.04875,
#    'frequency': 'Semiannual',
#    'maturityDate': '2043-04-16',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2013-04-16',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 79.79},
#   {'isincode': 'US900123BZ27',
#    'currency': 'USD',
#    'couponRate': 0.0625,
#    'frequency': 'Semiannual',
#    'maturityDate': '2022-09-26',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2012-01-26',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 104.232},
#   {'isincode': 'US900123AL40',
#    'currency': 'USD',
#    'couponRate': 0.11875,
#    'frequency': 'Semiannual',
#    'maturityDate': '2030-01-15',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2000-01-18',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 140.123},
#   {'isincode': 'US900123CG37',
#    'currency': 'USD',
#    'couponRate': 0.06625,
#    'frequency': 'Semiannual',
#    'maturityDate': '2045-02-17',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2014-02-19',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 94.8705},
#   {'isincode': 'US900123BJ84',
#    'currency': 'USD',
#    'couponRate': 0.06,
#    'frequency': 'Semiannual',
#    'maturityDate': '2041-01-14',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2011-01-12',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 89.991},
#   {'isincode': 'US900123AT75',
#    'currency': 'USD',
#    'couponRate': 0.08,
#    'frequency': 'Semiannual',
#    'maturityDate': '2034-02-14',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2004-01-14',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 113.027},
#   {'isincode': 'US900123CT57',
#    'currency': 'USD',
#    'couponRate': 0.07625,
#    'frequency': 'Semiannual',
#    'maturityDate': '2029-04-26',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2019-01-16',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 110.538},
#   {'isincode': 'US900123CJ75',
#    'currency': 'USD',
#    'couponRate': 0.0425,
#    'frequency': 'Semiannual',
#    'maturityDate': '2026-04-14',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2015-04-14',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 96.7405},
#   {'isincode': 'US900123CY43',
#    'currency': 'USD',
#    'couponRate': 0.0525,
#    'frequency': 'Semiannual',
#    'maturityDate': '2030-03-13',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2020-02-13',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 94.9505},
#   {'isincode': 'US900123BY51',
#    'currency': 'USD',
#    'couponRate': 0.05125,
#    'frequency': 'Semiannual',
#    'maturityDate': '2022-03-25',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2011-10-25',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 102.2565},
#   {'isincode': 'US900123CZ18',
#    'currency': 'USD',
#    'couponRate': 0.06375,
#    'frequency': 'Semiannual',
#    'maturityDate': '2025-10-14',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2020-10-14',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 106.1125},
#   {'isincode': 'US900123CR91',
#    'currency': 'USD',
#    'couponRate': 0.0725,
#    'frequency': 'Semiannual',
#    'maturityDate': '2023-12-23',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2018-10-23',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 108.136},
#   {'isincode': 'US900123CA66',
#    'currency': 'USD',
#    'couponRate': 0.0325,
#    'frequency': 'Semiannual',
#    'maturityDate': '2023-03-23',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2013-01-15',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 99.39},
#   {'isincode': 'US900123CV04',
#    'currency': 'USD',
#    'couponRate': 0.0635,
#    'frequency': 'Semiannual',
#    'maturityDate': '2024-08-10',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2019-07-10',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 105.9575},
#   {'isincode': 'US900123CK49',
#    'currency': 'USD',
#    'couponRate': 0.04875,
#    'frequency': 'Semiannual',
#    'maturityDate': '2026-10-09',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2016-03-09',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 98.551},
#   {'isincode': 'US900123CP36',
#    'currency': 'USD',
#    'couponRate': 0.05125,
#    'frequency': 'Semiannual',
#    'maturityDate': '2028-02-17',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2018-01-17',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 97.88},
#   {'isincode': 'US900123CX69',
#    'currency': 'USD',
#    'couponRate': 0.0425,
#    'frequency': 'Semiannual',
#    'maturityDate': '2025-03-13',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2020-02-13',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 98.5415},
#   {'isincode': 'US900123CW86',
#    'currency': 'USD',
#    'couponRate': 0.056,
#    'frequency': 'Semiannual',
#    'maturityDate': '2024-11-14',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2019-11-14',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 103.7},
#   {'isincode': 'US900123CL22',
#    'currency': 'USD',
#    'couponRate': 0.06,
#    'frequency': 'Semiannual',
#    'maturityDate': '2027-03-25',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2017-01-23',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 103.252},
#   {'isincode': 'US900123CF53',
#    'currency': 'USD',
#    'couponRate': 0.0575,
#    'frequency': 'Semiannual',
#    'maturityDate': '2024-03-22',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2014-01-29',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 104.1465},
#   {'isincode': 'US900123BB58',
#    'currency': 'USD',
#    'couponRate': 0.0725,
#    'frequency': 'Semiannual',
#    'maturityDate': '2038-03-05',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2008-03-05',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 104.8275},
#   {'isincode': 'US900123BG46',
#    'currency': 'USD',
#    'couponRate': 0.0675,
#    'frequency': 'Semiannual',
#    'maturityDate': '2040-05-30',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2010-01-12',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 97.992},
#   {'isincode': 'US900123BH29',
#    'currency': 'USD',
#    'couponRate': 0.05625,
#    'frequency': 'Semiannual',
#    'maturityDate': '2021-03-30',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2010-03-18',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 100.228},
#   {'isincode': 'US900123CQ19',
#    'currency': 'USD',
#    'couponRate': 0.06125,
#    'frequency': 'Semiannual',
#    'maturityDate': '2028-10-24',
#    'dayCounter': 'Thirty360E',
#    'calendar': 'Turkey',
#    'issueDate': '2018-04-24',
#    'redemption': 100,
#    'dateGeneration': 'Backward',
#    'businessDayConvention': 'ModifiedFollowing',
#    'maturityDayConvention': 'ModifiedFollowing',
#    'endOfMonth': True,
#    'yieldcurve': 'TRY USD Sovereign Curve',
#    'valuationDate': '2021-03-05',
#    'value': 102.7605}]}
