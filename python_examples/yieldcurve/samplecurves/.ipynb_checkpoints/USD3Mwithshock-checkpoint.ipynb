# %%
import json
import pandas as pd
import numpy as np
from datetime import datetime
import prettytable as pt
from matplotlib import pyplot as plt
import os 
import warnings
warnings.filterwarnings("ignore")

###################################################################################################
                                                                                                  #
from rhoova.Client import *                                                                       #   
#Register and get api key from https://app.rhoova.com/ for ClientConfig("api key", "api secret")  #
config = ClientConfig("", "")                                                                     #
api = Api(config)                                                                                 # 
                                                                                                  #
###################################################################################################

directory = os.path.normpath(os.getcwd() + os.sep + os.pardir+ os.sep+ os.pardir)
datadirectory=directory+"/data/yielddata/yielddata.csv"
confdir = os.path.normpath(os.getcwd() + os.sep + os.pardir)
configdirectory=directory+"/yieldcurve/samplecurves/config"



yielddata = pd.read_csv(datadirectory)
yielddata = yielddata.replace(np.nan, '', regex=True)

# %%
yieldcurveconfig=configdirectory+"/usd3m.json"
f = open (yieldcurveconfig, "r")
usd3ml = json.loads(f.read())

# %%
yieldcurve =  {
    "valuationDate": "2021-06-02",
#    "zeroRates": {
#        "analysisDates":['2021-06-04','2021-09-07','2021-09-16','2021-12-15','2022-03-15','2022-06-16',
#                         '2022-09-15','2022-12-21','2023-06-05','2024-06-04','2025-06-04','2026-06-04',
#                         '2027-06-04','2028-06-05','2029-06-04','2030-06-04','2031-06-04','2032-06-04',
#                         '2033-06-06','2036-06-04','2041-06-04','2046-06-04','2051-06-05','2061-06-06',
#                         '2071-06-04'],
#        "compounding": "Continuous",
#        "frequency": "Annual"
#    },
    "yieldCurve":usd3ml ,
    "yieldData": yielddata.to_dict('r')
}
try:
    result = api.createTask(CalculationType.YIELD_CURVE, yieldcurve,True)
    result=json.loads(result["result"])
except RhoovaError as e:
    e.printPretty()

# %%
zerorates=result.get("zeroRates"),
discountrates=result.get("discountRates")
dates=[]
forwarddates= {}
rhoovayieldcurvedicts = {}
rhoovayieldcurvediscounts = {}
for rhvzr in zerorates[0]:
    rhoovayieldcurvedicts[datetime.strptime(rhvzr.get('date'),'%Y-%m-%d').date()] = rhvzr.get('rate')*100
    dates.append(rhvzr.get('date'))

for rhv in discountrates:
    rhoovayieldcurvediscounts[datetime.strptime(rhv.get('date'), '%Y-%m-%d').date()] = rhv.get('rate')

# %%
bloombergzerorates=[0.13026,0.13026,0.12933,0.12543,0.1399,0.14339,0.15367,0.17113,0.2277,0.42095,0.66016,0.88188,
                    1.08274,1.25338,1.38811,1.49866,1.59246,1.67237,1.74239,1.88604,2.00444,2.04047,2.04536,
                    1.94349,1.81266]
bloombergdiscountrates=[1.00,0.999661,0.999635,0.999334,0.998908,0.998524,0.998006,0.997354,0.99545,0.98744,
                        0.973922,0.956841,0.937073,0.915908,0.894827,0.87375,0.852713,0.831854,0.811132,0.753435,
                        0.669541,0.600223,0.541152,0.459309,0.403764]

# %%
fig, ax = plt.subplots(figsize=(20, 10))

x=list(rhoovayieldcurvedicts.keys())
y1 =bloombergzerorates
y2 = list(rhoovayieldcurvedicts.values())


ax.plot(x,y1, 'g', label='Bloomberg', linewidth=2)
ax.plot(x,y2, 'ro', label='Rhoova', linewidth=4)
#
leg = ax.legend(prop={'size': 16});
plt.grid(linestyle='dashdot')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))

x=list(rhoovayieldcurvediscounts.keys())
y1 =bloombergdiscountrates
y2 = list(rhoovayieldcurvediscounts.values())

ax.plot(x,y1, 'g', label='Bloomberg', linewidth=2)
ax.plot(x,y2, 'ro', label='Rhoova', linewidth=12)

leg = ax.legend(prop={'size': 16});
plt.grid(linestyle='dashdot')
plt.show()

# %% [markdown]
# ![yieldcurve%20detail1.png](attachment:yieldcurve%20detail1.png)

# %% [markdown]
# ![yieldcurvevsbloomberg.png](attachment:yieldcurvevsbloomberg.png)

# %%
pTable = pt.PrettyTable(['Maturity','Rhoova ZeroRates','Bloomberg ZR','Rhoova Discount Rate','Bloomberg DR'])
i=0
for key, val in rhoovayieldcurvedicts.items():
    pTable.add_row([key, val,bloombergzerorates[i],rhoovayieldcurvediscounts.get(key),bloombergdiscountrates[i]])
    i=i+1
pTable.align = 'c'
pTable.float_format = '.6'
print(pTable)
# Out:
# +------------+------------------+--------------+----------------------+--------------+
# |  Maturity  | Rhoova ZeroRates | Bloomberg ZR | Rhoova Discount Rate | Bloomberg DR |
# +------------+------------------+--------------+----------------------+--------------+
# | 2021-06-04 |     0.131241     |   0.130260   |          1           |   1.000000   |
# | 2021-09-07 |     0.131241     |   0.130260   |       0.999661       |   0.999661   |
# | 2021-09-16 |     0.129294     |   0.129330   |       0.999634       |   0.999635   |
# | 2021-12-15 |     0.126840     |   0.125430   |       0.999327       |   0.999334   |
# | 2022-03-15 |     0.141452     |   0.139900   |       0.998896       |   0.998908   |
# | 2022-06-16 |     0.146213     |   0.143390   |       0.998490       |   0.998524   |
# | 2022-09-15 |     0.156033     |   0.153670   |       0.998004       |   0.998006   |
# | 2022-12-21 |     0.174670     |   0.171130   |       0.997301       |   0.997354   |
# | 2023-06-05 |     0.227694     |   0.227700   |       0.995450       |   0.995450   |
# | 2024-06-04 |     0.421321     |   0.420950   |       0.987440       |   0.987440   |
# | 2025-06-04 |     0.660611     |   0.660160   |       0.973922       |   0.973922   |
# | 2026-06-04 |     0.882365     |   0.881880   |       0.956841       |   0.956841   |
# | 2027-06-04 |     1.083242     |   1.082740   |       0.937073       |   0.937073   |
# | 2028-06-05 |     1.254368     |   1.253380   |       0.915907       |   0.915908   |
# | 2029-06-04 |     1.389081     |   1.388110   |       0.894826       |   0.894827   |
# | 2030-06-04 |     1.499593     |   1.498660   |       0.873748       |   0.873750   |
# | 2031-06-04 |     1.593358     |   1.592460   |       0.852710       |   0.852713   |
# | 2032-06-04 |     1.673651     |   1.672370   |       0.831851       |   0.831854   |
# | 2033-06-06 |     1.743603     |   1.742390   |       0.811128       |   0.811132   |
# | 2036-06-04 |     1.887527     |   1.886040   |       0.753423       |   0.753435   |
# | 2041-06-04 |     2.006126     |   2.004440   |       0.669499       |   0.669541   |
# | 2046-06-04 |     2.042175     |   2.040470   |       0.600169       |   0.600223   |
# | 2051-06-05 |     2.047029     |   2.045360   |       0.541092       |   0.541152   |
# | 2061-06-06 |     1.944875     |   1.943490   |       0.459297       |   0.459309   |
# | 2071-06-04 |     1.813584     |   1.812660   |       0.403818       |   0.403764   |
# +------------+------------------+--------------+----------------------+--------------+

# %%
parallelshock=configdirectory+"/parallelshock50bp.json"
f = open (parallelshock, "r")
parallelshock = json.loads(f.read())

# %%
usd3ml['applyShock']=parallelshock

# %%
result =  {
    "valuationDate": "2021-06-02",
    "endOfMonth": True,
    "yieldCurve":usd3ml ,
    "yieldData": yielddata.to_dict('r')
}
try:
    result = api.createTask(CalculationType.YIELD_CURVE, result,True)
    presult=json.loads(result["result"])
except RhoovaError as e:
    e.printPretty()

# %%
zerorates=presult.get("zeroRates"),
discountrates=presult.get("discountRates")
dates=[]
forwarddates= {}
rhoovapyieldcurvedicts = {}
rhoovapyieldcurvediscounts = {}
for rhvzr in zerorates[0]:
    rhoovapyieldcurvedicts[datetime.strptime(rhvzr.get('date'),'%Y-%m-%d').date()] = rhvzr.get('rate')*100
    dates.append(rhvzr.get('date'))

for rhv in discountrates:
    rhoovapyieldcurvediscounts[datetime.strptime(rhv.get('date'), '%Y-%m-%d').date()] = rhv.get('rate')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
bloombergshiftedmarketrates=[0.6285,0.627450119,0.619375077,0.668457736,0.652206235,0.690519723,0.758569906,
                              0.727600001,0.921499997,1.158000499,1.375930011,1.573450506,1.739165008,1.869239986,
                              1.974700034,2.064020038,2.140365541,2.2051,2.33950001,2.451399982,2.49000001,
                              2.501249969,2.43870002]
bloombergshiftedzerorates=[0.636701315,0.636701315,0.635835695,0.631919286,0.646367734,0.649841327,0.66009861,
                            0.677536876,0.793197438,0.965224039,1.193656939,1.40953834,1.608779834,1.777420208,
                            1.911516816,2.021093805,2.114737904,2.194914755,2.263818366,2.40714556,2.524893812,
                            2.558327731,2.560127643,2.445148585,2.298140635]
bloombergshifteddiscountrates=[1.00,0.998344205,0.998207333,0.99664694,0.994965734,0.993328101,0.991464397,
                                0.989566907,0.984239832,0.971432818,0.953344472,0.931913263,0.907945553,0.882880427,
                                0.858107337,0.833593682,0.809296711,0.785353749,0.7618784,0.69674511,0.603309686,
                                0.527291117,0.463662011,0.375737951,0.31669191]

# %%
fig, ax = plt.subplots(figsize=(20, 10))

x=list(rhoovapyieldcurvedicts.keys())
y1 =bloombergshiftedzerorates
y2 = list(rhoovapyieldcurvedicts.values())


ax.plot(x,y1, 'g', label='Bloomberg', linewidth=2)
ax.plot(x,y2, 'r', label='Rhoova', linewidth=2)

leg = ax.legend(prop={'size': 16});
plt.grid(linestyle='dashdot')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))

x=list(rhoovapyieldcurvediscounts.keys())
y1 =bloombergshifteddiscountrates
y2 = list(rhoovapyieldcurvediscounts.values())
y3 = list(rhoovapyieldcurvediscounts.values())


ax.plot(x,y1, 'g', label='Bloomberg', linewidth=2)
ax.plot(x,y2, 'ro', label='Pricing Engine', linewidth=8)
ax.plot(x,y3, 'bx', label='Rhoova', linewidth=4)


leg = ax.legend(prop={'size': 16});
plt.grid(linestyle='dashdot')
plt.show()

# %%
pTable = pt.PrettyTable(['Maturity','Rhoova ZeroRates','Bloomberg ZR','Rhoova Discount Rate','Bloomberg DR'])
i=0
for key, val in rhoovapyieldcurvedicts.items():
    pTable.add_row([key, val,bloombergshiftedzerorates[i],rhoovapyieldcurvediscounts.get(key),bloombergshifteddiscountrates[i]])
    i=i+1
pTable.align = 'c'
pTable.float_format = '.6'
print(pTable)
# Out:
# +------------+------------------+--------------+----------------------+--------------+
# |  Maturity  | Rhoova ZeroRates | Bloomberg ZR | Rhoova Discount Rate | Bloomberg DR |
# +------------+------------------+--------------+----------------------+--------------+
# | 2021-06-04 |     0.631241     |   0.636701   |          1           |   1.000000   |
# | 2021-09-07 |     0.631241     |   0.636701   |       0.998371       |   0.998344   |
# | 2021-09-16 |     0.629294     |   0.635836   |       0.998219       |   0.998207   |
# | 2021-12-15 |     0.626840     |   0.631919   |       0.996680       |   0.996647   |
# | 2022-03-15 |     0.641452     |   0.646368   |       0.995006       |   0.994966   |
# | 2022-06-16 |     0.646213     |   0.649841   |       0.993345       |   0.993328   |
# | 2022-09-15 |     0.656033     |   0.660099   |       0.991634       |   0.991464   |
# | 2022-12-21 |     0.674670     |   0.677537   |       0.989616       |   0.989567   |
# | 2023-06-05 |     0.727694     |   0.793197   |       0.985532       |   0.984240   |
# | 2024-06-04 |     0.921321     |   0.965224   |       0.972739       |   0.971433   |
# | 2025-06-04 |     1.160611     |   1.193657   |       0.954637       |   0.953344   |
# | 2026-06-04 |     1.382365     |   1.409538   |       0.933216       |   0.931913   |
# | 2027-06-04 |     1.583242     |   1.608780   |       0.909378       |   0.907946   |
# | 2028-06-05 |     1.754368     |   1.777420   |       0.884392       |   0.882880   |
# | 2029-06-04 |     1.889081     |   1.911517   |       0.859739       |   0.858107   |
# | 2030-06-04 |     1.999593     |   2.021094   |       0.835301       |   0.833594   |
# | 2031-06-04 |     2.093358     |   2.114738   |       0.811123       |   0.809297   |
# | 2032-06-04 |     2.173651     |   2.194915   |       0.787335       |   0.785354   |
# | 2033-06-06 |     2.243603     |   2.263818   |       0.763870       |   0.761878   |
# | 2036-06-04 |     2.387527     |   2.407146   |       0.698983       |   0.696745   |
# | 2041-06-04 |     2.506126     |   2.524894   |       0.605788       |   0.603310   |
# | 2046-06-04 |     2.542175     |   2.558328   |       0.529647       |   0.527291   |
# | 2051-06-05 |     2.547029     |   2.560128   |       0.465716       |   0.463662   |
# | 2061-06-06 |     2.444875     |   2.445149   |       0.376030       |   0.375738   |
# | 2071-06-04 |     2.313584     |   2.298141   |       0.314493       |   0.316692   |
# +------------+------------------+--------------+----------------------+--------------+

# %%
keyrateshock=configdirectory+"/keyrateshock.json"
f = open (keyrateshock, "r")
keyrateshock = json.loads(f.read())

# %%
usd3ml['applyShock']=keyrateshock

# %%
yieldcurve =  {
    "valuationDate": "2021-06-02",
    "endOfMonth": True,
    "yieldCurve":usd3ml ,
    "yieldData": yielddata.to_dict('r')
}
try:
    result = api.createTask(CalculationType.YIELD_CURVE, yieldcurve,True)
    krresult=json.loads(result["result"])
except RhoovaError as e:
    e.printPretty()

# %%
zerorates=krresult.get("zeroRates"),
discountrates=krresult.get("discountRates")
dates=[]
forwarddates= {}
rhoovakryieldcurvedicts = {}
rhoovakryieldcurvediscounts = {}
for rhvzr in zerorates[0]:
    rhoovakryieldcurvedicts[datetime.strptime(rhvzr.get('date'),'%Y-%m-%d').date()] = rhvzr.get('rate')*100
    dates.append(rhvzr.get('date'))

for rhv in discountrates:
    rhoovakryieldcurvediscounts[datetime.strptime(rhv.get('date'), '%Y-%m-%d').date()] = rhv.get('rate')

# %%
bloombergshiftedmarketrates2=[0.1285,0.127450119,0.119375077,0.168457736,0.152206235,0.190519723,0.258569906,
                             1.227600001,0.421499997,0.658000499,0.875930011,1.073450506,1.239165008,1.369239986,
                             1.474700034,3.564020038,1.640365541,1.7051,1.83950001,1.951399982,1.99000001,
                             2.001249969,1.93870002,1.85363996]
bloombergshiftedzerorates2=[0.1314,0.130262638,0.129325564,0.125427219,0.139902239,0.143384512,0.153666499,
                           0.171127066,1.233855314,0.419400528,0.657362026,0.878395501,1.080525856,1.251133521,
                           1.386437767,1.496877363,4.007172201,1.637389258,1.707879251,1.8557922,1.980338665,
                           2.020502028,2.028382992,1.931971567,1.805295275]
bloombergshifteddiscountrates2=[1.00,0.999661018,0.99963512,0.999333568,0.998908209,0.998524033,0.99800643,
                               0.997354552,0.975591905,0.98748546,0.974030666,0.957007701,0.93719758,0.916051971,
                               0.894946812,0.873889813,0.66969239,0.835063593,0.814501128,0.756863617,0.672778577,
                               0.603229448,0.543916534,0.461430517,0.405254036]

# %%
fig, ax = plt.subplots(figsize=(20, 10))

x=list(rhoovakryieldcurvedicts.keys())
y1 =bloombergshiftedzerorates2
y2 = list(rhoovakryieldcurvedicts.values())


ax.plot(x,y1, 'g', label='Bloomberg', linewidth=2)
ax.plot(x,y2, 'ro', label='Rhoova', linewidth=4)

leg = ax.legend(prop={'size': 16});
plt.grid(linestyle='dashdot')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))

x=list(rhoovakryieldcurvediscounts.keys())
y1 =bloombergshifteddiscountrates2
y2 = list(rhoovakryieldcurvediscounts.values())
y3 = list(rhoovakryieldcurvediscounts.values())


ax.plot(x,y1, 'g', label='Bloomberg', linewidth=2)
ax.plot(x,y2, 'ro', label='Pricing Engine', linewidth=8)
ax.plot(x,y3, 'bx', label='Rhoova', linewidth=4)


leg = ax.legend(prop={'size': 16});
plt.grid(linestyle='dashdot')
plt.show()

# %% [markdown]
# ![2y10010y200.png](attachment:2y10010y200.png)

# %%
pTable = pt.PrettyTable(['Maturity','Rhoova ZeroRates','Bloomberg ZR','Rhoova Discount Rate','Bloomberg DR'])
i=0
for key, val in rhoovakryieldcurvedicts.items():
    pTable.add_row([key, val,bloombergshiftedzerorates2[i],rhoovakryieldcurvediscounts.get(key),bloombergshifteddiscountrates2[i]])
    i=i+1
pTable.align = 'c'
pTable.float_format = '.6'
print(pTable)
# Out:
# +------------+------------------+--------------+----------------------+--------------+
# |  Maturity  | Rhoova ZeroRates | Bloomberg ZR | Rhoova Discount Rate | Bloomberg DR |
# +------------+------------------+--------------+----------------------+--------------+
# | 2021-06-04 |     0.131241     |   0.131400   |          1           |   1.000000   |
# | 2021-09-07 |     0.131241     |   0.130263   |       0.999661       |   0.999661   |
# | 2021-09-16 |     0.129294     |   0.129326   |       0.999634       |   0.999635   |
# | 2021-12-15 |     0.126840     |   0.125427   |       0.999327       |   0.999334   |
# | 2022-03-15 |     0.141452     |   0.139902   |       0.998896       |   0.998908   |
# | 2022-06-16 |     0.146213     |   0.143385   |       0.998490       |   0.998524   |
# | 2022-09-15 |     0.156033     |   0.153666   |       0.998004       |   0.998006   |
# | 2022-12-21 |     0.174670     |   0.171127   |       0.997301       |   0.997355   |
# | 2023-06-05 |     1.227694     |   1.233855   |       0.975712       |   0.975592   |
# | 2024-06-04 |     0.421321     |   0.419401   |       0.987440       |   0.987485   |
# | 2025-06-04 |     0.660611     |   0.657362   |       0.973922       |   0.974031   |
# | 2026-06-04 |     0.882365     |   0.878396   |       0.956841       |   0.957008   |
# | 2027-06-04 |     1.083242     |   1.080526   |       0.937073       |   0.937198   |
# | 2028-06-05 |     1.254368     |   1.251134   |       0.915907       |   0.916052   |
# | 2029-06-04 |     1.389081     |   1.386438   |       0.894826       |   0.894947   |
# | 2030-06-04 |     1.499593     |   1.496877   |       0.873748       |   0.873890   |
# | 2031-06-04 |     3.593358     |   4.007172   |       0.698140       |   0.669692   |
# | 2032-06-04 |     1.673651     |   1.637389   |       0.831851       |   0.835064   |
# | 2033-06-06 |     1.743603     |   1.707879   |       0.811128       |   0.814501   |
# | 2036-06-04 |     1.887527     |   1.855792   |       0.753423       |   0.756864   |
# | 2041-06-04 |     2.006126     |   1.980339   |       0.669499       |   0.672779   |
# | 2046-06-04 |     2.042175     |   2.020502   |       0.600169       |   0.603229   |
# | 2051-06-05 |     2.047029     |   2.028383   |       0.541092       |   0.543917   |
# | 2061-06-06 |     1.944875     |   1.931972   |       0.459297       |   0.461431   |
# | 2071-06-04 |     1.813584     |   1.805295   |       0.403818       |   0.405254   |
# +------------+------------------+--------------+----------------------+--------------+

# %%
# Rhoova does not change market rate and shifts only yield curve
#Change 2Y and 10Y market rate
newyielddata=yielddata[yielddata["valuationDate"]=="2021-06-02"]
twoyearshock=newyielddata[newyielddata["tenor"]=="2Y"]["value"]+100/10000
tenyearshock=newyielddata[newyielddata["tenor"]=="10Y"]["value"]+200/10000
newyielddata.at[newyielddata.index[newyielddata['tenor'] == "2Y"].tolist()[0],'value']=twoyearshock
newyielddata.at[newyielddata.index[newyielddata['tenor'] == "10Y"].tolist()[0],'value']=tenyearshock

del usd3ml['applyShock']

yieldcurve =  {
    "valuationDate": "2021-06-02",
    "endOfMonth": True,
    "yieldCurve":usd3ml ,
    "yieldData": newyielddata.to_dict('r')
}
try:
    result = api.createTask(CalculationType.YIELD_CURVE, yieldcurve,True)
    kr2result=json.loads(result["result"])
except RhoovaError as e:
    e.printPretty()
    
zerorates=kr2result.get("zeroRates"),
discountrates=kr2result.get("discountRates")
dates=[]
forwarddates= {}
rhoovakr2yieldcurvedicts = {}
rhoovakr2yieldcurvediscounts = {}
for rhvzr in zerorates[0]:
    rhoovakr2yieldcurvedicts[datetime.strptime(rhvzr.get('date'),'%Y-%m-%d').date()] = rhvzr.get('rate')*100
    dates.append(rhvzr.get('date'))

for rhv in discountrates:
    rhoovakr2yieldcurvediscounts[datetime.strptime(rhv.get('date'), '%Y-%m-%d').date()] = rhv.get('rate')
 
fig, ax = plt.subplots(figsize=(20, 10))

x=list(rhoovakr2yieldcurvedicts.keys())
y1 =bloombergshiftedzerorates2
y2 = list(rhoovakr2yieldcurvedicts.values())


ax.plot(x,y1, 'g', label='Bloomberg', linewidth=2)
ax.plot(x,y2, 'ro', label='Rhoova', linewidth=4)

leg = ax.legend(prop={'size': 16});
plt.grid(linestyle='dashdot')
plt.show()

pTable = pt.PrettyTable(['Maturity','Rhoova ZeroRates','Bloomberg ZR','Rhoova Discount Rate','Bloomberg DR'])
i=0
for key, val in rhoovakr2yieldcurvedicts.items():
    pTable.add_row([key, val,bloombergshiftedzerorates2[i],rhoovakr2yieldcurvediscounts.get(key),bloombergshifteddiscountrates2[i]])
    i=i+1
pTable.align = 'c'
pTable.float_format = '.6'
print(pTable)
# Out:
# +------------+------------------+--------------+----------------------+--------------+
# |  Maturity  | Rhoova ZeroRates | Bloomberg ZR | Rhoova Discount Rate | Bloomberg DR |
# +------------+------------------+--------------+----------------------+--------------+
# | 2021-06-04 |     0.131241     |   0.131400   |          1           |   1.000000   |
# | 2021-09-07 |     0.131241     |   0.130263   |       0.999661       |   0.999661   |
# | 2021-09-16 |     0.129294     |   0.129326   |       0.999634       |   0.999635   |
# | 2021-12-15 |     0.126840     |   0.125427   |       0.999327       |   0.999334   |
# | 2022-03-15 |     0.141452     |   0.139902   |       0.998896       |   0.998908   |
# | 2022-06-16 |     0.146213     |   0.143385   |       0.998490       |   0.998524   |
# | 2022-09-15 |     0.156033     |   0.153666   |       0.998004       |   0.998006   |
# | 2022-12-21 |     0.174670     |   0.171127   |       0.997301       |   0.997355   |
# | 2023-06-05 |     1.233908     |   1.233855   |       0.975590       |   0.975592   |
# | 2024-06-04 |     0.419039     |   0.419401   |       0.987508       |   0.987485   |
# | 2025-06-04 |     0.657914     |   0.657362   |       0.974027       |   0.974031   |
# | 2026-06-04 |     0.879463     |   0.878396   |       0.956980       |   0.957008   |
# | 2027-06-04 |     1.080251     |   1.080526   |       0.937241       |   0.937198   |
# | 2028-06-05 |     1.251377     |   1.251134   |       0.916099       |   0.916052   |
# | 2029-06-04 |     1.386160     |   1.386438   |       0.895035       |   0.894947   |
# | 2030-06-04 |     1.496770     |   1.496877   |       0.873970       |   0.873890   |
# | 2031-06-04 |     4.009670     |   4.007172   |       0.669672       |   0.669692   |
# | 2032-06-04 |     1.637699     |   1.637389   |       0.835148       |   0.835064   |
# | 2033-06-06 |     1.709060     |   1.707879   |       0.814499       |   0.814501   |
# | 2036-06-04 |     1.857092     |   1.855792   |       0.756870       |   0.756864   |
# | 2041-06-04 |     1.981366     |   1.980339   |       0.672823       |   0.672779   |
# | 2046-06-04 |     2.021761     |   2.020502   |       0.603240       |   0.603229   |
# | 2051-06-05 |     2.029856     |   2.028383   |       0.543887       |   0.543917   |
# | 2061-06-06 |     1.932828     |   1.931972   |       0.461516       |   0.461431   |
# | 2071-06-04 |     1.804920     |   1.805295   |       0.405571       |   0.405254   |
# +------------+------------------+--------------+----------------------+--------------+

# %%
nonparallel=configdirectory+"/nonparallelshock.json"
f = open (nonparallel, "r")
nonparallel = json.loads(f.read())

# %%
usd3ml['applyShock']=nonparallel

# %%
yieldcurve =  {
    "valuationDate": "2021-06-02",
    "endOfMonth": True,
    "yieldCurve":usd3ml ,
    "yieldData": yielddata.to_dict('r')
}

# %%
try:
    result = api.createTask(CalculationType.YIELD_CURVE, yieldcurve,True)
    npresult=json.loads(result["result"])
except RhoovaError as e:
    e.printPretty()

# %%
zerorates=npresult.get("zeroRates")
discountrates=npresult.get("discountRates")
dates=[]
forwarddates= {}
rhoovanpyieldcurvedicts = {}
rhoovanpyieldcurvediscounts = {}
for rhvzr in zerorates:
    rhoovanpyieldcurvedicts[datetime.strptime(rhvzr.get('date'),'%Y-%m-%d').date()] = rhvzr.get('rate')*100
    dates.append(rhvzr.get('date'))

for rhv in discountrates:
    rhoovanpyieldcurvediscounts[datetime.strptime(rhv.get('date'), '%Y-%m-%d').date()] = rhv.get('rate')

# %%
fig, ax = plt.subplots(figsize=(20, 10))

x=list(rhoovanpyieldcurvedicts.keys())
y1 =list(rhoovayieldcurvedicts.values())
y2 = list(rhoovanpyieldcurvedicts.values())


ax.plot(x,y1, 'g', label='Rhoova', linewidth=2)
ax.plot(x,y2, 'r', label='Nonparallel Shock', linewidth=2)

leg = ax.legend(prop={'size': 16});
plt.grid(linestyle='dashdot')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))

x=list(rhoovayieldcurvediscounts.keys())
y2 = list(rhoovanpyieldcurvediscounts.values())
y3 = list(rhoovanpyieldcurvediscounts.values())


ax.plot(x,y2, 'ro', label='Pricing Engine', linewidth=8)
ax.plot(x,y3, 'bx', label='Rhoova', linewidth=4)


leg = ax.legend(prop={'size': 16});
plt.grid(linestyle='dashdot')
plt.show()

# %%
pTable = pt.PrettyTable(['Maturity','Rhoova ZeroRates','Nonparallel Shock ZR','Rhoova Discount Rate','Nonparallel Shock DR'])
i=0
for key, val in rhoovayieldcurvedicts.items():
    pTable.add_row([key, val,rhoovanpyieldcurvedicts.get(key),rhoovayieldcurvediscounts.get(key),rhoovanpyieldcurvediscounts.get(key)])
    i=i+1
pTable.align = 'c'
pTable.float_format = '.6'
print(pTable)
# Out:
# +------------+------------------+----------------------+----------------------+----------------------+
# |  Maturity  | Rhoova ZeroRates | Nonparallel Shock ZR | Rhoova Discount Rate | Nonparallel Shock DR |
# +------------+------------------+----------------------+----------------------+----------------------+
# | 2021-06-04 |     0.131241     |       0.881241       |          1           |          1           |
# | 2021-09-07 |     0.131241     |       0.881241       |       0.999661       |       0.997726       |
# | 2021-09-16 |     0.129294     |       0.879294       |       0.999634       |       0.997512       |
# | 2021-12-15 |     0.126840     |       0.876840       |       0.999327       |       0.995359       |
# | 2022-03-15 |     0.141452     |       0.891452       |       0.998896       |       0.993066       |
# | 2022-06-16 |     0.146213     |       0.896213       |       0.998490       |       0.990782       |
# | 2022-09-15 |     0.156033     |       0.906033       |       0.998004       |       0.988465       |
# | 2022-12-21 |     0.174670     |       0.924670       |       0.997301       |       0.985795       |
# | 2023-06-05 |     0.227694     |       0.977694       |       0.995450       |       0.980609       |
# | 2024-06-04 |     0.421321     |       1.108973       |       0.987440       |       0.967278       |
# | 2025-06-04 |     0.660611     |       1.285741       |       0.973922       |       0.949870       |
# | 2026-06-04 |     0.882365     |       1.444973       |       0.956841       |       0.930300       |
# | 2027-06-04 |     1.083242     |       1.583329       |       0.937073       |       0.909373       |
# | 2028-06-05 |     1.254368     |       1.691759       |       0.915907       |       0.888278       |
# | 2029-06-04 |     1.389081     |       1.764124       |       0.894826       |       0.868376       |
# | 2030-06-04 |     1.499593     |       1.812115       |       0.873748       |       0.849514       |
# | 2031-06-04 |     1.593358     |       1.843358       |       0.852710       |       0.831656       |
# | 2032-06-04 |     1.673651     |       1.910318       |       0.831851       |       0.810475       |
# | 2033-06-06 |     1.743603     |       1.966863       |       0.811128       |       0.789676       |
# | 2036-06-04 |     1.887527     |       2.070861       |       0.753423       |       0.732986       |
# | 2041-06-04 |     2.006126     |       2.122793       |       0.669499       |       0.654058       |
# | 2046-06-04 |     2.042175     |       2.092175       |       0.600169       |       0.592714       |
# | 2051-06-05 |     2.047029     |       2.087024       |       0.541092       |       0.534638       |
# | 2061-06-06 |     1.944875     |       1.964864       |       0.459297       |       0.455639       |
# | 2071-06-04 |     1.813584     |       1.813584       |       0.403818       |       0.403818       |
# +------------+------------------+----------------------+----------------------+----------------------+
